# %% [markdown]
# # Text Adveture Game
#
# ## The Dark Night Rises
#
# ### Game Description
# Welcome to Gotham City. My game is based on the movie "The Dark Night Rises," in which The Joker has gone crazy and kidnapped Rachel and Harvey. The game's objective is to save Gotham City and rescue Harvey and Rachel from The Joker. For that to be accomplished, you need to defeat the henchmen hired by The Joker, determine their location, and crack some codes along the way.
#
# ### There are five stages in the game:
#
# * Determining User Mobility Item
#
# * Defeating The Henchman
#
# * Fight scene with The Joker
#
# * Meeting The Joker
#
# * Rachel and Harvey's Rescue
#
# #### Citations
#
# ASCII Art Batman - asciiart.eu. (n.d.). ASCII Art Batman - Asciiart.eu. Retrieved January 24, 2023, from https://www.asciiart.eu/comics/batman
#
# Kusterer, C. (2019). Python for Business Analytics [Review of Python for Business Analytics]. Chase Kusterer.
#
# time - How to make a countdown program in python. Stack Overflow. Retrieved January 24, 2023, from https://stackoverflow.com/questions/68427400/how-to-make-a-countdown-program-in-python
#
# Nolan, C. (Director). (2012). The Dark Knight Rises [Motion picture]. United States: Warner Bros. Pictures.
#
# Joker Text Art |. Emojicombos.com. Retrieved January 28, 2023, from https://emojicombos.com/joker-text-art

# %%
#(ASCII Art Batman - Asciiart.eu)
#Defining a Win Function for the Game
def Win ():
    print("Congratulations You have Won the Game!!")
#Graphic for Batman Logo
    print(""" 
                  .o888P     Y8o8Y     Y888o.
                 d88888      88888      88888b
                d888888b_  _d88888b_  _d888888b
                8888888888888888888888888888888
                8888888888888888888888888888888
                YJGS8P"Y888P"Y888P"Y888P"Y8888P
                 Y888   '8'   Y8P   '8'   888Y
                  '8o          V          o8'
                                            """)
#Input to check if the User would like to Play Again
    play_again = input("Would you like to play again? \n<Yes/no>\n")
    play_again = play_again.capitalize()

#Conditional Statments for User's Play_again Decision    
    if play_again == "Yes" or play_again == "Y" or play_again == "1":
        level_1()
    
    elif play_again == "No" or play_again == "N" or play_again == "2":
        print("Thanks for playing!")
    
    else:
        print('\nSomething went wrong')
#Win()                    
#(Joker Text Art)
def Lose():
    print("Joker:HA HA HA you thought you can defeat me. The Joker's reign continues. You lose!!")
    
    print("""
          


                            ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣠⣴⣤⣶⡶⠛⠉⠉⠀⣀⣀⣀⣤⣤⣤⣶⣶⣒⣛⣉⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
                ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣀⣴⣿⣿⣿⡿⠋⢀⣠⣴⣶⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⣶⢤⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
                ⠀⠀⠀⠀⠀⠀⠀⠀⢀⡴⣿⣿⣿⣿⣿⣿⣷⣾⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡿⣟⡽⣟⣫⣭⣶⣶⣿⣿⣦⣄⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
                ⠀⠀⠀⠀⠀⠀⠀⢠⠏⠀⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠿⠋⠙⠉⠁⠀⢿⣿⣿⣿⣿⡿⠿⠿⣿⡿⣶⣦⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣀⡄⠀
                ⠀⠀⠀⠀⠀⠀⣴⠃⠀⠀⠈⠻⠿⠿⠿⠿⠟⠛⠉⠁⠙⠿⠿⠛⠋⠉⠀⠀⠀⢀⣠⣴⣶⣾⣿⣿⣿⣿⣷⣶⣦⣙⠻⢿⣿⣿⣿⣶⣶⣶⣦⣤⣤⣴⢶⣾⠟⠀⠀
                ⠀⠀⠀⠀⠀⠰⡏⣴⣄⠀⠀⠀⠀⠀⢀⣠⣴⣤⣄⣀⠀⠀⠀⠀⠀⠀⢀⣴⣶⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿�
��⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠹⣄⠀⠀⠀⠀⠀⠀⠈⣳⢶⣿⣀⠀⠀⠀⠀⠀⠀⠀⢸⠁⠀⠀⠀⠀⠀
                ⠀⠀⠎⠀⣼⠋⠀⠰⢊⣯⡟⠀⢀⣀⡤⠶⠒⠉⠉⠁⠀⢻⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢠⣿⡄⠀⠀⠀⠀⢀⣾⠁⣸⠇⢹⠳⣄⠀⠀⠀⠀⠀⡜⠀⠀⠀⠀⠀⠀
                ⠀⠀⠀⠀⣯⢉⡶⡆⣸⡉⠓⠉⠉⠀⠀⠀⠀⠀⠀⠀⠀⠘⡆⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⣇⠹⡀⠀⠀⣰⠏⡾⠀⣿⠀⢸⠀⠈⣿⢦⡀⠀⢰⡇⠀⠀⠀⠀⠀⠀
                ⠀⠀⠀⢀⡿⠋⠁⠁⠉⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿⠀⢻⣀⡜⠁⢠⠇⠀⣧⠀⢸⠀⠀⡇⠀⠙⠲⡽⠁⠀⠀⠀⠀⠀⠀
                ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⣆⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿⠀⠀⠉⠀⠀⣿⠀⠀⣿⠀⢸⠀⢸⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
                ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠻⡀⠀⠀⠀⠀⠀⠀⠀⠀⢻⠀⠀⠀⠀⠀⠉⠉⠛⢿⡆⢸⡇⢸⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
                ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠻⡀⠀⠀⠀⠀⠀⠀⠀⠸⡄⠀⠀⠀⠀⠀⠀⠀⠘⣧⡾⠃⡜⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
                ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠻⣄⠀⠀⠀⠀⠀⠀⠀⣧⠀⠀⠀⠀⠀⠀⠀⠀⠉⠀⠀⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
                ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠙⠀⠀⠀⠀⠀⠀⠀⠿⠂⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠟⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀          
          
                                                                                                        """)
        
    play_again = input("Would you like to play again? \n<Yes/no>\n")
    play_again = play_again.capitalize()
    
    if play_again == "Yes" or play_again == "Y" or play_again == "1":
        level_1()
    
    elif play_again == "No" or play_again == "N" or play_again == "2":
        print("Thanks for playing!")
    
    else:
        print("Thanks for playing")

#Lose()                        

#Setting up level 1 and the Mobility Item that the User will Choose
def level_1():
    print("You're in level_1!\n")
    mobility_item = ["Batmobile","Batcycle","Batboat","Batcopter"]
    
    # User Input for the Inventory
    user_mobility = input(prompt = f"""
    Gear yourself up for battle. Please choose your means of transportation.
    {mobility_item}
    """)
    user_mobility = user_mobility.capitalize()

    #Selection Meassage for User for their Mobility Item
    if (user_mobility == "Batmobile") or (user_mobility == "Batcycle") or (user_mobility == "Batboat") or (user_mobility == "Batcopter"):
    
        print(f"""     
        Good Choice! I am sure you will be able to get there right on
        time using the {user_mobility}. Now go get The Joker and remember 
        to save Harvey and Rachehl!
        """)
        input(prompt='Press Enter to Level 2')
        level_2()
    else:
        print(f"""
        Sorry that choice is not available.""")
        level_1()
#level_1()
#---------------------------------------------Setting up Level 2------------------------------------------------------------- 
def level_2():
    print("You're in level_2!\n")

    #Giving the User to a choice to go back and change their mobility item    
    choice = input(prompt = "If you want to go back to your mobility selection type 1 to continue press 2")
   
    if (choice == '1'):
        level_1() 
    
    elif (choice == '2'):
        #Prompting the user the decision on what they want to do when they approach The Joker       
            combat_decision = input(prompt = f""" 
         The scene takes place in Gotham City on a dark and stormy night. The joker is
         dressed in his iconic purple suit. As you get closer, you can hear The Joker's maniac
         laugh you begin to investigate the place and you see a lot of henchmen in the
         surroundings. However, thanks to your detective skills, you were able to identify the Joker.
         vision.

         You have two options: 
        <1. Fight the Henchman or 2. Use the Grapple Gun to get to the Joker!>\n
        """)
           #Controlling for Case Senstivity      
            combat_decision = combat_decision.capitalize()

                #Creating the Conditional statement according to the user's input   
            if(combat_decision == "Fight the Henchman") or (combat_decision == "1"):
                    print(f"""
                Good Job. You defeated the heavily armed henchman after a long battle.
                However, The Joker manages to flee in the midst of the chaos. Hurry up 
                before he gets away!
                            """)
                    level_3()

            elif(combat_decision == "Use the Grapple Gun to fight the Joker" or combat_decision == "2"):
                    print(f"""
             Good Job. You made it to the floor, where the joker is.Get ready for combat and determine Harvey's
             and Rachel's location.

                    """)
                    level_3()
            else:
                print("Sorry that option is not available. Please choose again.")
                level_2()
    else:
        print('Sorry I did not quiet get that. I need you type 1 or 2 please.\n')
        level_2()

#level_2()
#--------------------------------------------Setting up Level 3------------------------------------------------------------- 

import time

def level_3():
    print("You're in level_3!\n")

    # Setting the scene of the battle scene between the Joker and Batman
    options = ["Run", "Fight", "Talk"]
    print("It's time for the fight. You finally get to confront The Joker.")
    while True:
        # Creating user input for the fight scene
        action_move = input(f"""What would you like to do? 
        
        <1. Run, 2.Fight, 3.Talk>\n""")
        
        action_move = action_move.capitalize()

        # Conditional statement for the dialogue of the fight scene
        if action_move in ['1',"Run"]:
            print("Batman: I can not do this anymore. You Win Joker")
            print("Joker: Tell your men they work for me now, this is my city!")
            Lose()
            break
        elif action_move in ['2',"Fight"]:
            print("Your anger gives you great power. But if you let it, it will destroy you… As it almost did to me.")
            print("Joker: And...here...we...go...")
            countdown(5)
            break
        elif action_move in ['3',"Talk"]:
            print("Batman: Let's talk sometimes people deserve a second chance.")
            print("Joker: Talk? I don't want to talk. I want to watch the world burn.")
            countdown(5)
            break
        else:
            print('Invalid option. Please try again.')
            
#(Time - How to Make a Countdown Program in Python)
# Creating a countdown for bomb detonation
def countdown(t):
    while t:
        mins, secs = divmod(t, 60)
        timeformat = '{:02d}:{:02d}'.format(mins, secs)
        print(timeformat, end='\r')
        time.sleep(1)
        t -= 1

    

    # Condition for when the bomb detonates
    print(f"""
    Boooom!!!! The sound of a large, detonated bomb.The Joker has apparently filled the building
     with heavy explosives. Quickly turn on your tactical mask so you can see again!\n
     """)
    # Creating night vision ability
    while True:
            
        tactical_mask = input("Type 1 to activate your tactical mask.")
        if tactical_mask == '1':
            print("Good Job!! You managed to activate your Tactical mask. Now hurry and relocate the Joker.!!")
            level_4()
            break
            
        else:
            print(" Sorry that option is not available. You need to type 1 to use your nightvision.")
            

            

#-------------------------------------------Setting up Level 4-------------------------------------------------------------
def level_4():
   
    print("You're in room_4!\n")
          
    print(f"""
    Well done for making it up until here. You have The Joker hanging by his feet. All you need to do now is
    is to determine Harvey and Rachel's location.
""")
    
    print(f""" 
    You begin beating up The Joker in order for him to reveal the locations of Harvey and Rachel. But then he claims that he
    wants to play a small guessing game with you and wants to have some fun first. He wants you to guess Rachel and Harvey's
    location and has given you four options.
    """)

    import random

    #Potential Addresses where Rachel and Harvey are being held
    addresses = ["1.Walnut Creek", "2.Concord", "3.San Francisco","4.Pleasant Hill"]

    #Function to shuffle the addressees where the Joker is holding them Hostage
    random.shuffle(addresses)
    correct_answer = addresses[0]
    
    #Determining the number of guesses for the user
    addresses.sort()
    guess = 2

    #Declaring the number of guesses the user can input to guess the correct 
    while guess > 0:
        for address in addresses:
            print(address)
        choice = input(prompt= '\n <What is your guess. Choose one number between 1-4.>\n')

            #Coniditonal statments for input responses 
        if choice.lower() in correct_answer.lower():
            print("Great Job!! You determined Rachel and Harvey's location.")
            level_5()
            break
            #Case Condiiton incase of incorrect guess
        elif choice.lower() not in correct_answer.lower():
            guess -= 1
            print("That's incorrect. You have 1 more chance.")
            #Finishing off with an else statement in case of error
        else:
            print("Something went wrong.")
                        
    Lose()
#-------------------------------------------Setting up Level 5-------------------------------------------------------------
def level_5():

    #Setting the Mobility item to get to the location to save Harvey and Rachel
    mobility_item = ["Batmobile","Batcycle","Batboat","Batcopter"]

    #Define User_moobility Variable
    user_mobility = input(prompt = f"""
    Now that you know where Harvey and Rachel are choose your means of transportation:
    {mobility_item}
                """)

    #Controlling Case Control    
    user_mobility = user_mobility.capitalize()

    #Printing Stament for your User_Mobility   
    if (user_mobility == "Batmobile") or (user_mobility == "Batcycle") or (user_mobility == "Batboat") or (user_mobility == "Batcopter"):
    
        print(f"""     
        Good Choice! I am sure you will be able to get there right on
        time using the {user_mobility}. Now go save Harvey and Rachel!
        """)
    #Bringing the User back to the Selction Mobility
    else:
        print(f"""
        Sorry that choice is not available. Choose again, Please.""")
        level_5()
    
    #Setting the Scene and getting ready to crack the door code    
    print ("You face one last task before you can save Harvey and Rachel, and that is to decode the door.")

    hint = input(prompt = 
                   f"""Would you like to take a hint before you try to break the door and break Batman's body.
    \n<Yes/No>\n
    """)
    #Controlling for Case Senstivity
    hint = hint.capitalize()
    
    #Giving the User a Hint to Solve the Code
    if hint == 'Yes':
        print(f""" The code is a number that can be divided by 5""")
    
    #Building the Case Statement
    elif hint == 'No':
        print(f""" Okay tough guy show me what you got!!""")
    
    #Controlling for Errors
    else:
        print("I don't what was that but okay! Show me what you got.")


    #Creating list for codes    
    codes = ["2023","1640","1212","3414"]

    door_key = 1640

##(Kusterer, 2019)
#Creating a For loop for cracking the door code

    while True:
          choice = input(prompt = f""" Guess your code from the following list {codes}""")
          
        #Converting the Choice from String to Integer
          try:
            choice = int(choice)
          
        #Controlling for errors
          except:
            input(prompt = f"""The number must be in digits. Press Enter to try again\n""")
            continue
          
        # Win Function 
          if choice == door_key:
            Win()
            break
          
        #Giving the User another chance to win the game
          elif choice != door_key:
            print("This is incorrect please try again")
            choice = input(prompt = f""" Guess your code from the following list {codes}""")
          
          else:
            print("Something went wrong please try again")
            

#level_5()


#Game Start Prompt
def game_start():
    answer = input(prompt= f"""\nWould you like to save Gotham City from The Joker.\n 
        \n<Yes/No>\n
    """)

    #Removing any Case Sensitivity
    answer = answer.casefold()

    #Conditional Condition for User Input's
    if (answer == 'yes'):
        
        print(f"""
        Welcome to Gotham City The Joker has kidnapped Rachael and 
        Harvey. You play as Batman, and you are racing against time 
        you need to find a way to defeat The Joker and save Rachel 
        and Harvey.
        """)
        input(prompt='<Press any key to Level 1>')
        
        level_1()
        

    elif (answer == 'no'):
        print( f"""
        Why So Serious? The Joker has taken over Gotham!!""")
        

    else: 
        print(f""" 
        Incorrect input. Try typing yes or no.""")
        game_start()
game_start()
